# %%
import numpy as np
import scipy.stats as S
import matplotlib.pyplot as plt

# %%
sample_data = np.random.rayleigh(scale=5,size=(1000,50))

# %%
sample_data
# Out:
# array([[ 8.15358153,  5.82044083, 10.11137096, ...,  8.56957632,
#          2.05608654,  8.9071547 ],
#        [18.29072179,  2.23543702,  4.27831861, ...,  8.39061513,
#          6.09214572,  6.26070791],
#        [ 4.76218252, 10.4168596 ,  0.97769375, ...,  2.95517095,
#          9.44588427,  3.68734031],
#        ...,
#        [ 3.70590763,  6.85651831,  7.93062789, ...,  2.82536255,
#          8.02712894,  7.33212686],
#        [ 6.09602441,  9.70538313,  7.82014794, ...,  5.85032543,
#          9.1310654 , 16.94816073],
#        [ 6.45674207,  0.99507709,  8.31972374, ...,  5.73923446,
#          4.06310805,  1.97699645]])

# %%
sample_data.shape
# Out:
# (1000, 50)

# %%
squared_data = sample_data**2
sample_mean = np.mean(squared_data,axis=1)
sample_mean = sample_mean/2
mvu_estimator = np.sqrt(sample_mean)

# %%
mvu_estimator
# Out:
# array([5.0145247 , 5.18626662, 4.50710918, 5.54751784, 5.01953692,
#        4.94216719, 5.08084672, 4.78938504, 5.00312233, 4.99818882,
#        5.42452711, 4.75424178, 5.33147541, 5.02349919, 5.18384584,
#        5.74584292, 5.05014423, 5.5333148 , 5.04833476, 5.29963879,
#        4.45064017, 5.0378389 , 5.09665605, 4.51508858, 5.67151428,
#        5.11342267, 4.45252934, 4.95562786, 4.95780393, 4.57153642,
#        4.9726274 , 5.02243644, 5.08345713, 5.16344952, 5.09457243,
#        4.00032205, 5.14319183, 5.04570502, 4.91830051, 5.05062805,
#        5.29690877, 4.98461603, 5.26790868, 4.74574134, 5.43884231,
#        5.17963263, 5.14568796, 5.21487157, 5.04068487, 5.07074307,
#        5.39298977, 4.62131238, 5.53536605, 4.31769743, 5.05011168,
#        5.48356683, 4.60266407, 5.07493563, 4.67866096, 5.38520147,
#        5.47542667, 4.27134842, 4.98188669, 5.67265808, 4.57499003,
#        5.8296567 , 4.98140737, 5.11649775, 4.6250148 , 5.03209003,
# ...

# %%
plt.hist(mvu_estimator)
# Out:
# (array([  7.,  19.,  56., 152., 236., 244., 160.,  88.,  30.,   8.]),
#  array([3.85391778, 4.07535303, 4.29678829, 4.51822354, 4.7396588 ,
#         4.96109405, 5.1825293 , 5.40396456, 5.62539981, 5.84683507,
#         6.06827032]),
#  <a list of 10 Patch objects>)

# %%
sample_mean = np.mean(mvu_estimator)

# %%
sample_mean
# Out:
# 4.991254145097046
